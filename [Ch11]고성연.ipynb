# %% [markdown]
# ### 인셉션 (Inception)
# - 작은 컨볼루션 계층을 매우 많이 연결한 이미지 인식 모델

# %%
# !tar -zxvf C:\Users\tjddu\Desktop\2020-MachineLearning-study\3min-Deeplearning-TensorFlow\workspace\flower_photos.tgz
# Out:
# x flower_photos/
# x flower_photos/roses/
# x flower_photos/roses/14810868100_87eb739f26_m.jpg
# x flower_photos/roses/1446090416_f0cad5fde4.jpg
# x flower_photos/roses/15319767030_e6c5602a77_m.jpg
# x flower_photos/roses/15032112248_30c5284e54_n.jpg
# x flower_photos/roses/7211616670_2d49ecb3a5_m.jpg
# x flower_photos/roses/15674450867_0ced942941_n.jpg
# x flower_photos/roses/17158274118_00ec99a23c.jpg
# x flower_photos/roses/14019883858_e5d2a0ec10_n.jpg
# x flower_photos/roses/8035908422_87220425d2_n.jpg
# x flower_photos/roses/14747962886_2bff6bb323_m.jpg
# x flower_photos/roses/4356781875_92c5cd93c0.jpg
# x flower_photos/roses/8524505546_b242bd4928_n.jpg
# x flower_photos/roses/9406573080_60eab9278e_n.jpg
# x flower_photos/roses/6039330368_c30ed224c4_m.jpg
# x flower_photos/roses/14414100710_753a36fce9.jpg
# x flower_photos/roses/3292434691_392071d702_n.jpg
# x flower_photos/roses/5273722065_c85d8543c2_m.jpg
# x flower_photos/roses/2215318403_06eb99176a.jpg
# ...

# %% [markdown]
# - retrain.py

# %%
# retrain.py 스크립트로 꽃 사진 학습시키기
# 디렉터리 이름을 레이블(꽃의 이름)로 하여 각 디렉터리에 있는 사진 학습

# !python retrain.py \
    # 학습할 사진을 인셉션용 학습 데이터로 변환해서 저장해둘 디렉터리
    --bottleneck_dir=./workspace/bottlenecks \
    # 인셉션 모델을 내려받을 경로
    --model_dir=./workspace/inception \
    # 학습된 모델을 저장할 경로
    # flowers_graph.pb 
    # -> 학습 결과를 프로토콜 버퍼(.pb) 데이터 형식으로 저장해둔 파일
    --output_graph=./workspace/flowers_graph.pb \
    # 레이블 이름들을 저장해둘 파일 경로
    --output_labels=./workspace/flowers_labels.txt \
    # 원본 이미지 경로
    --image_dir ./workspace/flower_photos \
    # 반복 학습 횟수
    --how_many_training_steps 1000
# Out:
# 2021-01-07 16:53:58.880235: I C:\tf_jenkins\workspace\rel-win\M\windows\PY\36\tensorflow\core\platform\cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX AVX2
# 2021-01-07 16:54:03.355249: W C:\tf_jenkins\workspace\rel-win\M\windows\PY\36\tensorflow\core\framework\op_def_util.cc:343] Op BatchNormWithGlobalNormalization is deprecated. It will cease to work in GraphDef version 9. Use tf.nn.batch_normalization().
# >> Downloading inception-2015-12-05.tgz 0.0%
# >> Downloading inception-2015-12-05.tgz 0.0%
# >> Downloading inception-2015-12-05.tgz 0.0%
# >> Downloading inception-2015-12-05.tgz 0.0%
# >> Downloading inception-2015-12-05.tgz 0.0%
# >> Downloading inception-2015-12-05.tgz 0.0%
# >> Downloading inception-2015-12-05.tgz 0.1%
# >> Downloading inception-2015-12-05.tgz 0.1%
# >> Downloading inception-2015-12-05.tgz 0.1%
# >> Downloading inception-2015-12-05.tgz 0.1%
# >> Downloading inception-2015-12-05.tgz 0.1%
# ...

# %%
# !pip3 install pillow

# %% [markdown]
# - predict.py

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sys

# %%
# app.flags 사용 -> 스크립트에서 받을 옵션과 기본값 설정
tf.app.flags.DEFINE_string("output_graph",
                           "./workspace/flowers_graph.pb",
                           "학습된 신경망이 저장된 위치")
tf.app.flags.DEFINE_string("output_labels",
                           "./workspace/flowers_labels.txt",
                           "학습할 레이블 데이터 파일")
tf.app.flags.DEFINE_boolean("show_image",
                            True,
                            "이미지 추론 후 이미지를 보여줍니다.")

FLAGS = tf.app.flags.FLAGS

# %%
# 테스트 결과 확인할 때 사용하기 위해, 파일에 담긴 꽃 이름 가져와 배열로 저장
def main(_):
    labels = [line.rstrip() for line in tf.gfile.GFile(FLAGS.output_labels)]
    # 학습 결과 읽어들여 신경망 그래프 생성
    with tf.gfile.FastGFile(FLAGS.output_graph, 'rb') as fp:
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(fp.read())
        tf.import_graph_def(graph_def, name='')

    with tf.Session() as sess:
        # 읽어들인 신경망 모델에서 예측에 사용할 텐서 지정
        # 저장되어있는 모델에서 최종 출력층 -> final_result
        logits = sess.graph.get_tensor_by_name('final_result:0')
        # 예측 스크립트 실행할 때 주어진 이름의 이미지 파일을 읽어들인 뒤, 
        # 그 이미지를 예측 모델에 넣어 예측 실행
        image = tf.gfile.FastGFile(sys.argv[1], 'rb').read()
        prediction = sess.run(logits, {'DecodeJpeg/contents:0': image})
        
    print('=== 예측 결과 ===')
    # 앞에서 읽어온 레이블(꽃 이름)에 해당하는 모든 예측결과 출력
    for i in range(len(labels)):
        name = labels[i]
        score = prediction[0][i]
        print('%s (%.2f%%)' % (name, score * 100))
        
    if FLAGS.show_image:
        img = mpimg.imread(sys.argv[1])
        plt.imshow(img)
        plt.show()

# %%
# 스크립트 실행 시 주어진 옵션들과 함께 main()함수 실행
if __name__ == "__main__":
    tf.app.run()

# %% [markdown]
# https://github.com/tensorflow/models
