# %%
import tensorflow as tf

# %%
hello = tf.constant('Hello, TensorFlow!')
print(hello)
# Out:
# Tensor("Const:0", shape=(), dtype=string)

# %%
# 그래프 생성

a = tf.constant(10)
b = tf.constant(32)
c = tf.add(a, b)
print(c)
# Out:
# Tensor("Add:0", shape=(), dtype=int32)

# %%
# 그래프의 실행은 Session안에서 이루어짐 (run메서드 이용)
# 모델 구성과 실행 분리

sess = tf.Session()

print(sess.run(hello))
print(sess.run([a,b,c]))

sess.close()
# Out:
# b'Hello, TensorFlow!'
# [10, 32, 42]

# %%
# placeholder : 그래프에 사용할 입력값 나중에 받기위해 사용하는 매개변수
X = tf.placeholder(tf.float32, [None, 3])
print(X)
# Out:
# Tensor("Placeholder:0", shape=(?, 3), dtype=float32)

# %%
x_data = [[1,2,3], [4,5,6]]

# %%
# 정규분포의 무작위 값으로 초기화
W = tf.Variable(tf.random_normal([3, 2]))
b = tf.Variable(tf.random_normal([2, 1]))

# %%
W = tf.Variable([[0.1, 0.1],[0.2, 0.2], [0.3, 0.3]])

# %%
expr = tf.matmul(X, W) + b

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

print("=== x_data ===")
print(x_data)
print("=== W ===")
print(sess.run(W))
print("=== b ===")
print(sess.run(b))
print("=== expr ===")
print(sess.run(expr, feed_dict={X: x_data}))

sess.close()
# Out:
# === x_data ===
# [[1, 2, 3], [4, 5, 6]]
# === W ===
# [[0.1 0.1]
#  [0.2 0.2]
#  [0.3 0.3]]
# === b ===
# [[-0.03363047]
#  [-0.6697929 ]]
# === expr ===
# [[1.3663696 1.3663696]
#  [2.5302072 2.5302072]]

# %%
x_data = [1,2,3]
y_data = [1,2,3]

# %%
# 균등분포의 무작위 값으로 초기화
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %%
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")

# %%
# X와 Y의 상관관계 분석 수식
# W는 가중치, b는 편향
hypothesis = W * X + b

# %%
# 손실함수
# 손실값: 실제값과 모델 예측값 차이 나타내는 값
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# 최적화 함수 이용해 손실값 최소화
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)
train_op = optimizer.minimize(cost)

# %%
# 그래프 실행하여 학습
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(100) :
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})
    
    
        print(step, cost_val, sess.run(W), sess.run(b))
      
print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 0 0.7733863 [1.1329174] [-0.201266]
# 1 0.015947146 [1.0893676] [-0.21417977]
# 2 0.006580695 [1.0916297] [-0.20709087]
# 3 0.006165274 [1.088945] [-0.2023246]
# 4 0.0058711986 [1.0868595] [-0.19743769]
# 5 0.005592288 [1.0847657] [-0.19269393]
# 6 0.0053266524 [1.0827286] [-0.18806142]
# 7 0.0050736307 [1.0807399] [-0.18354057]
# 8 0.004832627 [1.0787989] [-0.17912838]
# 9 0.0046030823 [1.0769047] [-0.17482226]
# 10 0.004384421 [1.075056] [-0.17061965]
# 11 0.0041761585 [1.0732516] [-0.16651809]
# 12 0.0039777854 [1.0714908] [-0.1625151]
# 13 0.0037888456 [1.0697721] [-0.15860838]
# 14 0.0036088685 [1.0680948] [-0.15479554]
# 15 0.0034374492 [1.0664579] [-0.15107438]
# 16 0.0032741735 [1.0648602] [-0.14744265]
# 17 0.0031186407 [1.0633011] [-0.1438982]
# 18 0.0029705027 [1.0617794] [-0.14043899]
# 19 0.0028293983 [1.0602943] [-0.13706294]
# 20 0.0026950042 [1.0588448] [-0.13376807]
# 21 0.0025669914 [1.0574303] [-0.13055237]
# 22 0.0024450591 [1.0560496] [-0.127414]
# 23 0.0023289144 [1.0547023] [-0.12435104]
# 24 0.0022182898 [1.0533873] [-0.12136175]
# 25 0.0021129232 [1.0521039] [-0.11844432]
# 26 0.00201255 [1.0508513] [-0.11559699]
# 27 0.0019169584 [1.0496289] [-0.11281813]
# 28 0.0018259003 [1.0484358] [-0.11010604]
# 29 0.0017391723 [1.0472715] [-0.10745917]
# 30 0.0016565603 [1.0461351] [-0.10487594]
# 31 0.0015778687 [1.0450261] [-0.10235478]
# 32 0.0015029191 [1.0439436] [-0.09989426]
# 33 0.0014315307 [1.0428873] [-0.09749286]
# 34 0.0013635326 [1.0418563] [-0.09514923]
# 35 0.001298762 [1.0408502] [-0.09286189]
# 36 0.001237071 [1.0398681] [-0.09062958]
# 37 0.0011783094 [1.0389097] [-0.08845091]
# 38 0.0011223386 [1.0379744] [-0.08632459]
# 39 0.0010690241 [1.0370615] [-0.08424941]
# 40 0.001018246 [1.0361705] [-0.08222411]
# 41 0.0009698795 [1.035301] [-0.08024748]
# 42 0.0009238098 [1.0344524] [-0.07831837]
# 43 0.0008799273 [1.0336242] [-0.07643568]
# 44 0.0008381325 [1.0328158] [-0.07459822]
# 45 0.00079831394 [1.032027] [-0.07280488]
# 46 0.0007603963 [1.0312572] [-0.0710547]
# 47 0.000724278 [1.0305057] [-0.06934663]
# 48 0.0006898733 [1.0297724] [-0.06767956]
# 49 0.0006571058 [1.0290567] [-0.06605262]
# 50 0.0006258933 [1.0283581] [-0.06446476]
# 51 0.00059616234 [1.0276765] [-0.06291506]
# 52 0.0005678424 [1.0270112] [-0.06140262]
# 53 0.0005408711 [1.0263618] [-0.05992656]
# 54 0.0005151782 [1.0257281] [-0.05848598]
# 55 0.00049070653 [1.0251096] [-0.05708002]
# 56 0.00046739785 [1.024506] [-0.05570786]
# 57 0.00044519486 [1.023917] [-0.05436867]
# 58 0.00042404942 [1.0233419] [-0.05306172]
# 59 0.00040390738 [1.0227808] [-0.05178613]
# 60 0.00038471943 [1.0222332] [-0.0505412]
# 61 0.00036644758 [1.0216987] [-0.04932626]
# 62 0.00034904116 [1.021177] [-0.0481405]
# 63 0.000332461 [1.020668] [-0.04698322]
# 64 0.00031666897 [1.0201712] [-0.04585378]
# 65 0.00030162602 [1.0196862] [-0.04475149]
# 66 0.00028729954 [1.019213] [-0.04367568]
# 67 0.00027365168 [1.0187511] [-0.04262574]
# 68 0.00026065393 [1.0183004] [-0.04160105]
# 69 0.00024827244 [1.0178604] [-0.040601]
# 70 0.00023647914 [1.0174311] [-0.03962497]
# 71 0.00022524579 [1.0170121] [-0.03867242]
# 72 0.00021454733 [1.0166031] [-0.03774278]
# 73 0.00020435631 [1.016204] [-0.03683548]
# 74 0.00019465032 [1.0158144] [-0.03594999]
# 75 0.00018540426 [1.0154343] [-0.03508578]
# 76 0.00017659727 [1.0150633] [-0.03424233]
# 77 0.00016820761 [1.0147011] [-0.03341917]
# 78 0.00016021814 [1.0143478] [-0.0326158]
# 79 0.00015260653 [1.0140028] [-0.03183175]
# 80 0.0001453583 [1.0136663] [-0.03106652]
# 81 0.00013845561 [1.0133376] [-0.03031974]
# 82 0.00013187742 [1.013017] [-0.02959084]
# 83 0.00012561212 [1.0127041] [-0.02887949]
# 84 0.00011964639 [1.0123987] [-0.02818525]
# 85 0.00011396346 [1.0121007] [-0.02750769]
# 86 0.00010854862 [1.0118098] [-0.02684643]
# 87 0.000103393286 [1.0115259] [-0.02620108]
# 88 9.848251e-05 [1.0112488] [-0.02557121]
# 89 9.3804905e-05 [1.0109783] [-0.02495651]
# 90 8.93492e-05 [1.0107144] [-0.02435656]
# 91 8.510315e-05 [1.0104569] [-0.023771]
# 92 8.106062e-05 [1.0102056] [-0.02319955]
# 93 7.72106e-05 [1.0099602] [-0.02264188]
# 94 7.3543546e-05 [1.0097208] [-0.02209757]
# 95 7.005024e-05 [1.009487] [-0.02156637]
# 96 6.672213e-05 [1.0092591] [-0.0210479]
# 97 6.355313e-05 [1.0090364] [-0.02054196]
# 98 6.0534152e-05 [1.0088192] [-0.02004813]
# 99 5.7659603e-05 [1.0086071] [-0.0195662]
# X: 5, Y: [5.0234694]
# X: 2.5, Y: [2.5019515]
